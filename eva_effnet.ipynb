# %% [markdown]
# # HOW TO RUN THIS FILE
# 1. edit the ROOT_PATH variable to match the path from your google drive to the eva shared folder
# 2. make sure that the runtime type is set to GPU. the code requires CUDA to work. (you can set it to CPU only mode, but it's about 10x slower)

# %%
# !nvidia-smi
# Out:
# Sun Dec  5 22:03:44 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    40W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import sys
# EDIT THIS VARIABLE:
#ROOT_PATH = "/content/drive/MyDrive/CS245 Project Shared/eva"
ROOT_PATH = "/content/drive/MyDrive/CS245 Project/CS245 Project Shared/eva"
SRC_PATH = os.path.join(ROOT_PATH, "src")
sys.path.append(SRC_PATH)

# %% [markdown]
# # Copy from GCP bucket

# %%
from google.colab import auth
auth.authenticate_user()
project_id = "personal-243018"
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
#
#
# To take a quick anonymous survey, run:
#   $ gcloud survey
#
# gs://benl_eva_bucket/

# %%
bucket_name = "benl_eva_bucket"
#!gsutil -m cp -r "/content/drive/MyDrive/CS245 Project Shared/eva/data/en(fr)_dbp15k_link_img_dict_full.pkl" gs://{bucket_name}/
for i in range(15):
    # !gsutil -m cp -r gs://{bucket_name}/{i}.pkl.gz "/content/drive/MyDrive/CS245 Project/CS245 Project Shared/eva/data/img_dict_pkls/"
# Out:
# Copying gs://benl_eva_bucket/0.pkl.gz...
# \ [1/1 files][399.1 MiB/399.1 MiB] 100% Done
# Operation completed over 1 objects/399.1 MiB.
# Copying gs://benl_eva_bucket/1.pkl.gz...
# - [1/1 files][646.4 MiB/646.4 MiB] 100% Done  50.7 MiB/s ETA 00:00:00
# Operation completed over 1 objects/646.4 MiB.
# Copying gs://benl_eva_bucket/2.pkl.gz...
# \ [1/1 files][762.2 MiB/762.2 MiB] 100% Done  52.0 MiB/s ETA 00:00:00
# Operation completed over 1 objects/762.2 MiB.
# Copying gs://benl_eva_bucket/3.pkl.gz...
# - [1/1 files][852.8 MiB/852.8 MiB] 100% Done  55.4 MiB/s ETA 00:00:00
# Operation completed over 1 objects/852.8 MiB.
# Copying gs://benl_eva_bucket/4.pkl.gz...
# - [1/1 files][615.2 MiB/615.2 MiB] 100% Done  47.9 MiB/s ETA 00:00:00
# Operation completed over 1 objects/615.2 MiB.
# Copying gs://benl_eva_bucket/5.pkl.gz...
# | [1/1 files][ 1016 MiB/ 1016 MiB] 100% Done  54.6 MiB/s ETA 00:00:00
# Operation completed over 1 objects/1016.8 MiB.
# Copying gs://benl_eva_bucket/6.pkl.gz...
# / [1/1 files][705.7 MiB/705.7 MiB] 100% Done  40.7 MiB/s ETA 00:00:00
# Operation completed over 1 objects/705.7 MiB.
# Copying gs://benl_eva_bucket/7.pkl.gz...
# | [1/1 files][781.0 MiB/781.0 MiB] 100% Done  60.6 MiB/s ETA 00:00:00
# Operation completed over 1 objects/781.0 MiB.
# Copying gs://benl_eva_bucket/8.pkl.gz...
# \ [1/1 files][890.7 MiB/890.7 MiB] 100% Done  32.0 MiB/s ETA 00:00:00
# Operation completed over 1 objects/890.7 MiB.
# Copying gs://benl_eva_bucket/9.pkl.gz...
# - [1/1 files][805.6 MiB/805.6 MiB] 100% Done  44.2 MiB/s ETA 00:00:00
# Operation completed over 1 objects/805.6 MiB.
# Copying gs://benl_eva_bucket/10.pkl.gz...
# | [1/1 files][739.9 MiB/739.9 MiB] 100% Done  80.7 MiB/s ETA 00:00:00
# Operation completed over 1 objects/739.9 MiB.
# Copying gs://benl_eva_bucket/11.pkl.gz...
# \ [1/1 files][608.5 MiB/608.5 MiB] 100% Done  55.1 MiB/s ETA 00:00:00
# Operation completed over 1 objects/608.5 MiB.
# Copying gs://benl_eva_bucket/12.pkl.gz...
# | [1/1 files][511.6 MiB/511.6 MiB] 100% Done  46.0 MiB/s ETA 00:00:00
# Operation completed over 1 objects/511.6 MiB.
# Copying gs://benl_eva_bucket/13.pkl.gz...
# \ [1/1 files][482.5 MiB/482.5 MiB] 100% Done  26.7 MiB/s ETA 00:00:00
# Operation completed over 1 objects/482.5 MiB.
# Copying gs://benl_eva_bucket/14.pkl.gz...
# - [1/1 files][ 66.8 MiB/ 66.8 MiB] 100% Done
# Operation completed over 1 objects/66.8 MiB.

# %% [markdown]
# # EVA Code

# %%
from run_dbp15k import *
def run_eva(emb_sizes=(100,100,200), gcn_emb_size=200, verbose=True, save_emb=False):
    parser = argparse.ArgumentParser()
    parser.add_argument("--file_dir", type=str, default="data/DBP15K/zh_en", required=False, help="input dataset file directory, ('data/DBP15K/zh_en', 'data/DWY100K/dbp_wd')")
    parser.add_argument("--rate", type=float, default=0.3, help="training set rate")
    
    parser.add_argument("--cuda", action="store_true", default=True, help="whether to use cuda or not")
    parser.add_argument("--seed", type=int, default=2021, help="random seed")
    parser.add_argument("--epochs", type=int, default=1000, help="number of epochs to train")
    parser.add_argument("--check_point", type=int, default=100, help="check point")
    parser.add_argument("--hidden_units", type=str, default="128,128,128", help="hidden units in each hidden layer(including in_dim and out_dim), splitted with comma")
    parser.add_argument("--heads", type=str, default="2,2", help="heads in each gat layer, splitted with comma")
    parser.add_argument("--instance_normalization", action="store_true", default=False, help="enable instance normalization")
    parser.add_argument("--lr", type=float, default=0.005, help="initial learning rate")
    parser.add_argument("--weight_decay", type=float, default=0, help="weight decay (L2 loss on parameters)")
    parser.add_argument("--dropout", type=float, default=0.0, help="dropout rate for layers")
    parser.add_argument("--attn_dropout", type=float, default=0.0, help="dropout rate for gat layers")
    parser.add_argument("--dist", type=int, default=2, help="L1 distance or L2 distance. ('1', '2')")
    parser.add_argument("--csls", action="store_true", default=False, help="use CSLS for inference")
    parser.add_argument("--csls_k", type=int, default=10, help="top k for csls")
    parser.add_argument("--il", action="store_true", default=False, help="Iterative learning?")
    parser.add_argument("--semi_learn_step", type=int, default=10, help="If IL, what's the update step?")
    parser.add_argument("--il_start", type=int, default=500, help="If Il, when to start?")
    parser.add_argument("--bsize", type=int, default=7500, help="batch size")
    parser.add_argument("--unsup", action="store_true", default=False)
    parser.add_argument("--unsup_k", type=int, default=1000, help="|visual seed|")
    #parser.add_argument("--long_tail_analysis", action="store_true", default=False)
    parser.add_argument("--lta_split", type=int, default=0, help="split in {0,1,2,3,|splits|-1}")
    args = argparse.Namespace( 
        file_dir=os.path.join(ROOT_PATH, "data/DBP15K/fr_en"), 
        rate=0.3, 
        lr=0.0005, 
        epochs=50, #1000 originally
        hidden_units=f"400,400,{gcn_emb_size}", 
        check_point=50, 
        bsize=7500, 
        il=False, # True originally 
        il_start=500, 
        semi_learn_step=5, 
        csls=True, 
        csls_k=3, 
        seed=0,
    )
    args = parser.parse_args(args=[], namespace=args)
    main(
        args, 
        emb_sizes=emb_sizes, 
        save_emb=save_emb, 
        root_path=ROOT_PATH,
        verbose=verbose
    )

# %%
# default run:
results = run_eva()

# %% [markdown]
# # EfficientNet Encodings
#
# First we investigate what format the image features need to be in.

# %%
import pickle

# %%
# load image dictionary
ori_img_features_path = os.path.join(ROOT_PATH,"data/pkls/fr_en_GA_id_img_feature_dict.pkl")
with open(ori_img_features_path, 'rb') as f:
    img_dict = pickle.load(f)
print("example of an item:")
print(list(img_dict.items())[0])
print("number of embeddings:")
print(len(img_dict.keys()))
# Out:
# example of an item:
# (7656, array([1.0869268 , 0.12827268, 0.02897369, ..., 0.3845102 , 0.0988225 ,
#        0.15103804], dtype=float32))
# number of embeddings:
# 28032

# %% [markdown]
# It appears to be a dictionary with keys being the entity id and the value being the image feature vector.
#
# We can recover the mapping between the IDs and the link names like so:

# %%
FILE_DIR = os.path.join(ROOT_PATH, "data/DBP15K/fr_en")
ent2id_dict, _, _, _, _, _ = read_raw_data(FILE_DIR, [1,2])
list(ent2id_dict.items())[0]
# Out:
# loading raw data...
# ('http://fr.dbpedia.org/resource/Saint-Joseph-de-Coleraine', 0)

# %%
import gzip
import time

# %% [markdown]
# Now we make a list of the english and french labels we have:

# %%
# check if we already extracted the labels
en_labels_path = os.path.join(ROOT_PATH, "data", "en_labels.pkl")
fr_labels_path = os.path.join(ROOT_PATH, "data", "fr_labels.pkl")
img_dict_path = os.path.join(ROOT_PATH, "data", "img_dict_pkls")
def extract_labels(path):
    labels = list()
    for dirent in os.scandir(path):
        tic = time.time()
        with gzip.open(dirent.path) as f:
            data = pickle.load(f)
            labels += list(data.keys())
            del data
        print(f"Loaded {dirent.name} in {time.time() - tic:.2f}s, num_labels = {len(labels)}")
    print(f"{len(labels)} labels loaded")
    return labels

if os.path.isfile(en_labels_path):
    print("English labels found; loading...")
    with open(en_labels_path, "rb") as f:
        en_labels = pickle.load(f)
else:
    print("English labels not found; extracting...")
    en_labels = extract_labels(os.path.join(img_dict_path, "en_fr_english_imgs"))
if os.path.isfile(fr_labels_path):
    print("French labels found; loading...")
    with open(fr_labels_path, "rb") as f:
        fr_labels = pickle.load(f)
else:
    print("French labels not found; extracting...")
    fr_labels = extract_labels(os.path.join(img_dict_path, "en_fr_french_imgs"))
# Out:
# English labels not found; extracting...
# Loaded 0.pkl.gz in 11.31s, num_labels = 1000
# Loaded 1.pkl.gz in 13.31s, num_labels = 2000
# Loaded 2.pkl.gz in 15.81s, num_labels = 3000
# Loaded 3.pkl.gz in 17.40s, num_labels = 4000
# Loaded 4.pkl.gz in 12.71s, num_labels = 5000
# Loaded 5.pkl.gz in 19.89s, num_labels = 6000
# Loaded 6.pkl.gz in 13.97s, num_labels = 7000
# Loaded 7.pkl.gz in 19.46s, num_labels = 8000
# Loaded 8.pkl.gz in 18.08s, num_labels = 9000
# Loaded 9.pkl.gz in 16.57s, num_labels = 10000
# Loaded 10.pkl.gz in 20.86s, num_labels = 11000
# Loaded 11.pkl.gz in 13.44s, num_labels = 12000
# Loaded 12.pkl.gz in 12.08s, num_labels = 13000
# Loaded 13.pkl.gz in 11.69s, num_labels = 14000
# Loaded 14.pkl.gz in 3.02s, num_labels = 14174
# 14174 labels loaded
# French labels not found; extracting...
# Loaded 0.pkl.gz in 9.29s, num_labels = 1000
# Loaded 1.pkl.gz in 13.53s, num_labels = 2000
# Loaded 10.pkl.gz in 8.03s, num_labels = 3000
# Loaded 11.pkl.gz in 4.05s, num_labels = 4000
# Loaded 12.pkl.gz in 3.92s, num_labels = 5000
# Loaded 13.pkl.gz in 52.29s, num_labels = 5858
# Loaded 2.pkl.gz in 15.65s, num_labels = 6858
# Loaded 3.pkl.gz in 21.91s, num_labels = 7858
# Loaded 4.pkl.gz in 22.58s, num_labels = 8858
# Loaded 5.pkl.gz in 20.07s, num_labels = 9858
# Loaded 6.pkl.gz in 12.40s, num_labels = 10858
# Loaded 7.pkl.gz in 15.34s, num_labels = 11858
# Loaded 8.pkl.gz in 17.68s, num_labels = 12858
# Loaded 9.pkl.gz in 12.94s, num_labels = 13858
# 13858 labels loaded

# %%
with open(en_labels_path, "wb") as f:
    pickle.dump(en_labels, f)
with open(fr_labels_path, "wb") as f:
    pickle.dump(fr_labels, f)

# %%
print(len(en_labels), len(fr_labels), len(en_labels) + len(fr_labels))
print(en_labels[0])
print(fr_labels[0])
# Out:
# 14174 13858 28032
# http://dbpedia.org/resource/United_States
# http://fr.dbpedia.org/resource/États-Unis

# %% [markdown]
# now we translate these labels into ids

# %%
labels = en_labels + fr_labels
enfr_ids = list()
num_en_labels = 0
num_fr_labels = 0
for label in labels:
    if label not in ent2id_dict:
        print(f"Could not find {label}")
        continue
    if "//dbpedia" in label:
        num_en_labels += 1
    elif "//fr.dbpedia" in label:
        num_fr_labels += 1
    enfr_ids.append(ent2id_dict[label])
print(f"en labels: {num_en_labels}; fr labels: {num_fr_labels}")
print(f"total labels: {len(enfr_ids)}")
# Out:
# en labels: 14174; fr labels: 13858
# total labels: 28032

# %% [markdown]
# ## Testing EffNet Pretrained
# let's check out one of the images to see how we can do inference on them

# %%
filepath = os.path.join(ROOT_PATH, "data", "img_dict_pkls", "0.pkl.gz")
with gzip.open(filepath) as f:
    data = pickle.load(f)
img = data[labels[0]]

# %%
transforms.ToTensor()(img.convert("RGB")).shape
# Out:
# torch.Size([3, 158, 300])

# %%
import PIL
from torchvision import transforms, models, datasets

# %%
efficientnet_b0 = models.efficientnet_b0(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-3dd342df.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-3dd342df.pth
#   0%|          | 0.00/20.5M [00:00<?, ?B/s]

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
preprocess = transforms.Compose(
    [transforms.Resize(256),
     transforms.CenterCrop(224),
     transforms.ToTensor(),
     normalize])
batch_t = None
for i in range(5):
    img_t = preprocess(data[labels[i]].convert("RGB"))
    img_t = torch.unsqueeze(img_t, 0)
    if batch_t is None:
        batch_t = img_t
    else:
        batch_t = torch.cat([batch_t, img_t])
print(img_t.shape)
print(batch_t.shape)
# Out:
# torch.Size([1, 3, 224, 224])
# torch.Size([5, 3, 224, 224])

# %%
imgfeatures = None
def featurehook(model, input, output):
    global imgfeatures
    imgfeatures = output.detach()
efficientnet_b0.avgpool.register_forward_hook(featurehook)

# %%
efficientnet_b0.eval()
output = efficientnet_b0(batch_t)
print(output.shape)
print(torch.flatten(imgfeatures, 1).shape)
# Out:
# torch.Size([5, 1000])
# torch.Size([5, 1280])

# %% [markdown]
# ## Extracting image features for EffNet

# %%
import PIL
from torchvision import transforms, models, datasets

# %%
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                    std=[0.229, 0.224, 0.225])
preprocess = transforms.Compose(
    [transforms.Resize(256),
     transforms.CenterCrop(224),
     transforms.ToTensor(),
     normalize])
def extract_effnet_features(model, 
                            ent2id_dict, 
                            preprocess=preprocess, 
                            batch_size=185, 
                            use_cuda=True,
                            verbose=True):
    imgfeatures = None
    def featurehook(model, input, output):
        global imgfeatures
        imgfeatures = output.detach()
    model.avgpool.register_forward_hook(featurehook)
    model.eval()

    def run_model(model, batch_t, all_img_features):
        global imgfeatures
        tic = time.time()
        torch.cuda.empty_cache()
        if use_cuda:
            batch_t = batch_t.cuda()
        model(batch_t)
        if verbose:
            print(f"Inference in {time.time()-tic:.2f}s")
            print(torch.flatten(imgfeatures, 1).shape)
        if use_cuda:
            imgfeatures = imgfeatures.cpu()
        if all_img_features is None:
            all_img_features = torch.flatten(imgfeatures, 1).numpy()
        else:
            all_img_features = np.concatenate((all_img_features, 
                                            torch.flatten(imgfeatures, 1).numpy()))
        return all_img_features

    all_img_features = None
    en_dict_path = os.path.join(ROOT_PATH, "data", "img_dict_pkls", "en_fr_english_imgs")
    fr_dict_path = os.path.join(ROOT_PATH, "data", "img_dict_pkls", "en_fr_french_imgs")
    id_list = list()
    for dirent in list(os.scandir(en_dict_path)) + list(os.scandir(fr_dict_path)):
        batch_t = None
        tic = time.time()
        with gzip.open(dirent.path) as f:
            data = pickle.load(f)
            if "english" in dirent.path:
                print(f"Loaded english/{dirent.name} in {time.time()-tic:.2f}s")
            else:
                print(f"Loaded french/{dirent.name} in {time.time()-tic:.2f}s")
            tic = time.time()
            for label, img in data.items():
                id_list.append(ent2id_dict[label])
                img_t = preprocess(img.convert("RGB"))
                img_t = torch.unsqueeze(img_t, 0)
                if batch_t is None:
                    batch_t = img_t
                else:
                    batch_t = torch.cat([batch_t, img_t])
                if batch_t.shape[0] == batch_size:
                    if verbose:
                        print(f"Prepared batch ({batch_size}) in {time.time()-tic:.2f}s")
                    all_img_features = run_model(model, batch_t, all_img_features)                    
                    del batch_t
                    del img_t
                    batch_t = None
                    tic = time.time()
            # run on remainder
            if batch_t is not None:
                all_img_features = run_model(model, batch_t, all_img_features)                    
    return id_list, all_img_features

# %%
efficientnet_b0 = models.efficientnet_b0(pretrained=True)
#efficientnet_b0.cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-3dd342df.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-3dd342df.pth
#   0%|          | 0.00/20.5M [00:00<?, ?B/s]

# %%
id_list, all_img_features = extract_effnet_features(efficientnet_b0, ent2id_dict, use_cuda=False)
# Out:
# Loaded english/0.pkl.gz in 8.12s
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Prepared batch (185) in 2.33s
# Inference in 20.57s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.77s
# Inference in 8.78s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.34s
# Inference in 8.70s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.45s
# Inference in 8.76s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.50s
# Inference in 8.60s
# torch.Size([185, 1280])
# Inference in 4.06s
# torch.Size([75, 1280])
# Loaded english/1.pkl.gz in 14.13s
# Prepared batch (185) in 2.47s
# Inference in 8.83s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.71s
# Inference in 8.14s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.62s
# Inference in 8.15s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.76s
# Inference in 8.12s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.72s
# Inference in 8.08s
# torch.Size([185, 1280])
# Inference in 3.40s
# torch.Size([75, 1280])
# Loaded english/2.pkl.gz in 15.18s
# Prepared batch (185) in 2.46s
# Inference in 8.52s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.55s
# Inference in 8.17s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.54s
# Inference in 8.14s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.42s
# Inference in 8.13s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.62s
# Inference in 8.10s
# torch.Size([185, 1280])
# Inference in 3.29s
# torch.Size([75, 1280])
# Loaded english/3.pkl.gz in 16.88s
# Prepared batch (185) in 2.57s
# Inference in 8.64s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.42s
# Inference in 7.64s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.84s
# Inference in 7.59s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.41s
# Inference in 7.63s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.97s
# Inference in 7.66s
# torch.Size([185, 1280])
# Inference in 3.26s
# torch.Size([75, 1280])
# Loaded english/4.pkl.gz in 13.50s
# Prepared batch (185) in 2.58s
# Inference in 7.85s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.64s
# Inference in 7.67s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.37s
# Inference in 7.69s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.35s
# Inference in 7.68s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.33s
# Inference in 7.78s
# torch.Size([185, 1280])
# Inference in 3.31s
# torch.Size([75, 1280])
# Loaded english/5.pkl.gz in 18.87s
# Prepared batch (185) in 3.18s
# Inference in 8.81s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.64s
# Inference in 7.88s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.72s
# Inference in 7.90s
# torch.Size([185, 1280])
# Prepared batch (185) in 3.16s
# Inference in 7.93s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.99s
# Inference in 7.94s
# torch.Size([185, 1280])
# Inference in 3.29s
# torch.Size([75, 1280])
# Loaded english/6.pkl.gz in 14.99s
# Prepared batch (185) in 2.59s
# Inference in 8.23s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.45s
# Inference in 8.09s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.40s
# Inference in 8.07s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.70s
# Inference in 8.05s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.73s
# Inference in 8.06s
# torch.Size([185, 1280])
# Inference in 3.18s
# torch.Size([75, 1280])
# Loaded english/7.pkl.gz in 15.59s
# Prepared batch (185) in 2.35s
# Inference in 8.48s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.46s
# Inference in 8.17s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.81s
# Inference in 8.11s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.62s
# Inference in 8.08s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.82s
# Inference in 8.09s
# torch.Size([185, 1280])
# Inference in 3.47s
# torch.Size([75, 1280])
# Loaded english/8.pkl.gz in 16.67s
# Prepared batch (185) in 2.58s
# Inference in 8.58s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.56s
# Inference in 10.11s
# torch.Size([185, 1280])
# Prepared batch (185) in 6.45s
# Inference in 12.25s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.86s
# Inference in 8.29s
# torch.Size([185, 1280])
# Prepared batch (185) in 3.01s
# Inference in 8.28s
# torch.Size([185, 1280])
# Inference in 3.52s
# torch.Size([75, 1280])
# Loaded english/9.pkl.gz in 16.87s
# Prepared batch (185) in 2.52s
# Inference in 8.46s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.78s
# Inference in 8.44s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.73s
# Inference in 8.50s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.81s
# Inference in 8.44s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.82s
# Inference in 8.40s
# torch.Size([185, 1280])
# Inference in 3.38s
# torch.Size([75, 1280])
# Loaded english/10.pkl.gz in 20.84s
# Prepared batch (185) in 3.08s
# Inference in 9.12s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.87s
# Inference in 8.60s
# torch.Size([185, 1280])
# Prepared batch (185) in 3.87s
# Inference in 8.54s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.74s
# Inference in 8.58s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.56s
# Inference in 8.62s
# torch.Size([185, 1280])
# Inference in 3.52s
# torch.Size([75, 1280])
# Loaded english/11.pkl.gz in 13.55s
# Prepared batch (185) in 2.41s
# Inference in 9.08s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.68s
# Inference in 9.05s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.45s
# Inference in 9.04s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.63s
# Inference in 8.98s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.51s
# Inference in 9.03s
# torch.Size([185, 1280])
# Inference in 3.07s
# torch.Size([75, 1280])
# Loaded english/12.pkl.gz in 12.69s
# Prepared batch (185) in 2.54s
# Inference in 8.89s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.32s
# Inference in 8.75s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.45s
# Inference in 8.74s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.41s
# Inference in 8.76s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.74s
# Inference in 8.73s
# torch.Size([185, 1280])
# Inference in 3.18s
# torch.Size([75, 1280])
# Loaded english/13.pkl.gz in 11.50s
# Prepared batch (185) in 2.33s
# Inference in 8.12s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.63s
# Inference in 7.82s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.61s
# Inference in 7.89s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.53s
# Inference in 7.83s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.28s
# Inference in 7.84s
# torch.Size([185, 1280])
# Inference in 3.07s
# torch.Size([75, 1280])
# Loaded english/14.pkl.gz in 3.03s
# Inference in 7.56s
# torch.Size([174, 1280])
# Loaded french/0.pkl.gz in 8.41s
# Prepared batch (185) in 2.18s
# Inference in 7.57s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.48s
# Inference in 7.41s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.38s
# Inference in 7.39s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.27s
# Inference in 7.37s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.66s
# Inference in 7.41s
# torch.Size([185, 1280])
# Inference in 3.07s
# torch.Size([75, 1280])
# Loaded french/1.pkl.gz in 13.58s
# Prepared batch (185) in 2.87s
# Inference in 7.81s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.44s
# Inference in 7.69s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.52s
# Inference in 7.71s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.40s
# Inference in 7.71s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.44s
# Inference in 14.38s
# torch.Size([185, 1280])
# Inference in 3.47s
# torch.Size([75, 1280])
# Loaded french/10.pkl.gz in 7.76s
# Prepared batch (185) in 2.52s
# Inference in 7.79s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.28s
# Inference in 7.52s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.92s
# Inference in 7.51s
# torch.Size([185, 1280])
# Prepared batch (185) in 3.13s
# Inference in 16.65s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.54s
# Inference in 7.51s
# torch.Size([185, 1280])
# Inference in 3.35s
# torch.Size([75, 1280])
# Loaded french/11.pkl.gz in 4.16s
# Prepared batch (185) in 2.23s
# Inference in 7.48s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.17s
# Inference in 7.52s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.20s
# Inference in 7.48s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.17s
# Inference in 7.49s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.17s
# Inference in 7.49s
# torch.Size([185, 1280])
# Inference in 2.61s
# torch.Size([75, 1280])
# Loaded french/12.pkl.gz in 4.07s
# Prepared batch (185) in 2.22s
# Inference in 7.53s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.10s
# Inference in 7.48s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.21s
# Inference in 7.58s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.07s
# Inference in 7.51s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.16s
# Inference in 7.54s
# torch.Size([185, 1280])
# Inference in 2.63s
# torch.Size([75, 1280])
# Loaded french/13.pkl.gz in 41.37s
# Prepared batch (185) in 2.22s
# Inference in 10.74s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.24s
# Inference in 9.26s
# torch.Size([185, 1280])
# Prepared batch (185) in 4.22s
# Inference in 9.26s
# torch.Size([185, 1280])
# Prepared batch (185) in 7.05s
# Inference in 8.64s
# torch.Size([185, 1280])
# Inference in 6.00s
# torch.Size([118, 1280])
# Loaded french/2.pkl.gz in 15.90s
# Prepared batch (185) in 2.58s
# Inference in 8.96s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.65s
# Inference in 8.24s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.64s
# Inference in 8.26s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.70s
# Inference in 8.24s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.68s
# Inference in 8.33s
# torch.Size([185, 1280])
# Inference in 2.60s
# torch.Size([75, 1280])
# Loaded french/3.pkl.gz in 21.10s
# Prepared batch (185) in 2.84s
# Inference in 7.40s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.80s
# Inference in 7.45s
# torch.Size([185, 1280])
# Prepared batch (185) in 3.18s
# Inference in 9.00s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.94s
# Inference in 8.60s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.70s
# Inference in 8.54s
# torch.Size([185, 1280])
# Inference in 2.64s
# torch.Size([75, 1280])
# Loaded french/4.pkl.gz in 22.69s
# Prepared batch (185) in 2.72s
# Inference in 9.52s
# torch.Size([185, 1280])
# Prepared batch (185) in 3.12s
# Inference in 9.00s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.58s
# Inference in 8.99s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.59s
# Inference in 9.02s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.64s
# Inference in 9.02s
# torch.Size([185, 1280])
# Inference in 2.60s
# torch.Size([75, 1280])
# Loaded french/5.pkl.gz in 20.56s
# Prepared batch (185) in 2.90s
# Inference in 9.22s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.53s
# Inference in 8.62s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.79s
# Inference in 8.63s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.74s
# Inference in 8.64s
# torch.Size([185, 1280])
# Prepared batch (185) in 3.18s
# Inference in 8.60s
# torch.Size([185, 1280])
# Inference in 2.61s
# torch.Size([75, 1280])
# Loaded french/6.pkl.gz in 12.77s
# Prepared batch (185) in 2.77s
# Inference in 9.15s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.52s
# Inference in 8.59s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.44s
# Inference in 10.59s
# torch.Size([185, 1280])
# Prepared batch (185) in 6.31s
# Inference in 16.87s
# torch.Size([185, 1280])
# Prepared batch (185) in 3.00s
# Inference in 8.73s
# torch.Size([185, 1280])
# Inference in 2.87s
# torch.Size([75, 1280])
# Loaded french/7.pkl.gz in 15.57s
# Prepared batch (185) in 4.58s
# Inference in 14.37s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.82s
# Inference in 8.41s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.83s
# Inference in 8.44s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.96s
# Inference in 8.46s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.47s
# Inference in 8.40s
# torch.Size([185, 1280])
# Inference in 2.63s
# torch.Size([75, 1280])
# Loaded french/8.pkl.gz in 17.86s
# Prepared batch (185) in 2.75s
# Inference in 10.87s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.80s
# Inference in 9.74s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.70s
# Inference in 9.81s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.86s
# Inference in 9.76s
# torch.Size([185, 1280])
# Prepared batch (185) in 3.11s
# Inference in 9.73s
# torch.Size([185, 1280])
# Inference in 2.73s
# torch.Size([75, 1280])
# Loaded french/9.pkl.gz in 12.96s
# Prepared batch (185) in 2.75s
# Inference in 9.84s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.78s
# Inference in 8.92s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.69s
# Inference in 8.85s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.26s
# Inference in 8.85s
# torch.Size([185, 1280])
# Prepared batch (185) in 2.82s
# Inference in 8.88s
# torch.Size([185, 1280])
# Inference in 2.67s
# torch.Size([75, 1280])

# %%
print(len(id_list))
print(all_img_features.shape)
# Out:
# 28032
# (28032, 1280)

# %%
all_img_features[0:2]
# Out:
# array([[ 0.5572252 , -0.2117167 , -0.1850568 , ..., -0.15802604,
#         -0.20168622,  0.23016961],
#        [-0.00828076, -0.08807116,  0.0238584 , ..., -0.08425538,
#         -0.10938895, -0.10650282]], dtype=float32)

# %%
np.save(os.path.join(ROOT_PATH, "data", "effnet_b0_imgfeatures.npy"), all_img_features)

# %% [markdown]
# Now we try efficientnet b7

# %%
# the input size is different, so we need to change the preprocessing step
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                    std=[0.229, 0.224, 0.225])
preprocess_b7 = transforms.Compose(
    [transforms.Resize(633),
     transforms.CenterCrop(600),
     transforms.ToTensor(),
     normalize])
efficientnet_b7 = models.efficientnet_b7(pretrained=True)
efficientnet_b7.cuda()
id_list_b7, all_img_features_b7 = extract_effnet_features(
    efficientnet_b7,
    ent2id_dict,
    preprocess=preprocess_b7,
    batch_size=1,
    use_cuda=True,
    verbose=False)
# Out:
# Loaded english/0.pkl.gz in 7.44s
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py:960: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Loaded english/1.pkl.gz in 12.89s
# Loaded english/2.pkl.gz in 15.64s
# Loaded english/3.pkl.gz in 16.64s
# Loaded english/4.pkl.gz in 18.51s
# Loaded english/5.pkl.gz in 22.97s
# Loaded english/6.pkl.gz in 15.20s
# Loaded english/7.pkl.gz in 16.36s
# Loaded english/8.pkl.gz in 16.65s
# Loaded english/9.pkl.gz in 20.98s
# Loaded english/10.pkl.gz in 21.65s
# Loaded english/11.pkl.gz in 12.97s
# Loaded english/12.pkl.gz in 11.98s
# Loaded english/13.pkl.gz in 10.76s
# Loaded english/14.pkl.gz in 2.89s
# Loaded french/0.pkl.gz in 8.47s
# Loaded french/1.pkl.gz in 13.05s
# Loaded french/10.pkl.gz in 7.38s
# Loaded french/11.pkl.gz in 3.44s
# Loaded french/12.pkl.gz in 3.74s
# Loaded french/13.pkl.gz in 43.05s
# Loaded french/2.pkl.gz in 15.56s
# Loaded french/3.pkl.gz in 20.87s
# Loaded french/4.pkl.gz in 20.15s
# Loaded french/5.pkl.gz in 19.68s
# Loaded french/6.pkl.gz in 11.73s
# Loaded french/7.pkl.gz in 15.75s
# Loaded french/8.pkl.gz in 17.24s
# Loaded french/9.pkl.gz in 12.43s

# %% [markdown]
# total runtime: 2h 30m

# %%
np.save(os.path.join(ROOT_PATH, "data", "effnet_b7_imgfeatures.npy"), all_img_features_b7)

# %%
with open(os.path.join(ROOT_PATH, "data", "effnet_b7_img_ids.pkl"), "wb") as f:
    pickle.dump(id_list_b7, f)

# %% [markdown]
# # Failed attempt to open super large pkl file

# %%
import PIL

# %% [markdown]
# They provide the original images as a dictionary with keys being the entity label and the value being the image:

# %%
fr_en_images_path = os.path.join(ROOT_PATH, "data", "en(fr)_dbp15k_link_img_dict_full.pkl")
f = open(fr_en_images_path, 'rb')
data = f.read(int(1e9))
print(data[30:90])
# Out:
# b'resource/United_Statesq\x01cPIL.PngImagePlugin\nPngImageFile\nq\x02)'

# %%
fr_en_images_path = os.path.join(ROOT_PATH, "data", "en(fr)_dbp15k_link_img_dict_full.pkl")
f = open(fr_en_images_path, 'rb')
#elems = sPickle.s_load(f)

# %%
def s_load(file_obj):
    """ load contents from file_obj, returning a generator that yields one
        element at a time """
    cur_elt = []
    for line in file_obj:
        cur_elt.append(line)

        if line == '\n':
            pickled_elt_str = ''.join(cur_elt)
            elt = loads(pickled_elt_str)
            cur_elt = []
            yield elt

# %%
elem1 = next(elems)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-6-08f0ff7104a1> in <module>()
# ----> 1 elem1 = next(elems)
#
# /content/drive/MyDrive/CS245 Project Shared/eva/src/sPickle.py in s_load(file_obj)
#      70     element at a time'''
#      71     for barray in readByteArrayStream(file_obj):
# ---> 72         yield loads(barray)
#      73
#
# UnpicklingError: pickle data was truncated

# %%
data[1860:2000]
# Out:
# b'K\xfdK\xfeK\xfeK\xfeK\xffK\xffK\xffeB('

# %%
import pickletools

# %%
pickletools.dis(data[:1875])
# Out:
#     0: \x80 PROTO      3
#     2: }    EMPTY_DICT
#     3: q    BINPUT     0
#     5: (    MARK
#     6: X        BINUNICODE 'http://dbpedia.org/resource/United_States'
#    52: q        BINPUT     1
#    54: c        GLOBAL     'PIL.PngImagePlugin PngImageFile'
#    87: q        BINPUT     2
#    89: )        EMPTY_TUPLE
#    90: \x81     NEWOBJ
#    91: q        BINPUT     3
#    93: ]        EMPTY_LIST
#    94: q        BINPUT     4
#    96: (        MARK
#    97: }            EMPTY_DICT
#    98: q            BINPUT     5
#   100: (            MARK
#   101: X                BINUNICODE 'gamma'
#   111: q                BINPUT     6
#   113: G                BINFLOAT   0.45455
#   122: X                BINUNICODE 'chromaticity'
#   139: q                BINPUT     7
#   141: (                MARK
#   142: G                    BINFLOAT   0.3127
#   151: G                    BINFLOAT   0.329
#   160: G                    BINFLOAT   0.64
#   169: G                    BINFLOAT   0.33
#   178: G                    BINFLOAT   0.3
#   187: G                    BINFLOAT   0.6
#   196: G                    BINFLOAT   0.15
#   205: G                    BINFLOAT   0.06
#   214: t                    TUPLE      (MARK at 141)
#   215: q                BINPUT     8
#   217: X                BINUNICODE 'date:create'
#   233: q                BINPUT     9
#   235: X                BINUNICODE '2017-08-09T19:06:42+00:00'
#   265: q                BINPUT     10
#   267: X                BINUNICODE 'date:modify'
#   283: q                BINPUT     11
#   285: X                BINUNICODE '2017-08-09T19:06:42+00:00'
#   315: q                BINPUT     12
#   317: u                SETITEMS   (MARK at 100)
#   318: X            BINUNICODE 'P'
#   324: q            BINPUT     13
#   326: M            BININT2    300
#   329: K            BININT1    158
#   331: \x86         TUPLE2
#   332: q            BINPUT     14
#   334: ]            EMPTY_LIST
#   335: q            BINPUT     15
#   337: (            MARK
#   338: K                BININT1    60
#   340: K                BININT1    59
#   342: K                BININT1    110
#   344: K                BININT1    178
#   346: K                BININT1    34
#   348: K                BININT1    52
#   350: K                BININT1    64
#   352: K                BININT1    63
#   354: K                BININT1    113
#   356: K                BININT1    115
#   358: K                BININT1    114
#   360: K                BININT1    151
#   362: K                BININT1    114
#   364: K                BININT1    114
#   366: K                BININT1    150
#   368: K                BININT1    179
#   370: K                BININT1    178
#   372: K                BININT1    198
#   374: K                BININT1    178
#   376: K                BININT1    177
#   378: K                BININT1    198
#   380: K                BININT1    62
#   382: K                BININT1    61
#   384: K                BININT1    112
#   386: K                BININT1    238
#   388: K                BININT1    238
#   390: K                BININT1    242
#   392: K                BININT1    240
#   394: K                BININT1    240
#   396: K                BININT1    244
#   398: K                BININT1    63
#   400: K                BININT1    62
#   402: K                BININT1    112
#   404: K                BININT1    84
#   406: K                BININT1    84
#   408: K                BININT1    128
#   410: K                BININT1    211
#   412: K                BININT1    211
#   414: K                BININT1    223
#   416: K                BININT1    255
#   418: K                BININT1    255
#   420: K                BININT1    255
#   422: K                BININT1    216
#   424: K                BININT1    216
#   426: K                BININT1    226
#   428: K                BININT1    88
#   430: K                BININT1    87
#   432: K                BININT1    131
#   434: K                BININT1    158
#   436: K                BININT1    157
#   438: K                BININT1    183
#   440: K                BININT1    253
#   442: K                BININT1    253
#   444: K                BININT1    254
#   446: K                BININT1    254
#   448: K                BININT1    254
#   450: K                BININT1    254
#   452: K                BININT1    171
#   454: K                BININT1    170
#   456: K                BININT1    192
#   458: K                BININT1    65
#   460: K                BININT1    64
#   462: K                BININT1    113
#   464: K                BININT1    62
#   466: K                BININT1    61
#   468: K                BININT1    111
#   470: K                BININT1    236
#   472: K                BININT1    236
#   474: K                BININT1    241
#   476: K                BININT1    104
#   478: K                BININT1    103
#   480: K                BININT1    142
#   482: K                BININT1    201
#   484: K                BININT1    200
#   486: K                BININT1    215
#   488: K                BININT1    165
#   490: K                BININT1    164
#   492: K                BININT1    188
#   494: K                BININT1    61
#   496: K                BININT1    60
#   498: K                BININT1    111
#   500: K                BININT1    145
#   502: K                BININT1    144
#   504: K                BININT1    173
#   506: K                BININT1    162
#   508: K                BININT1    162
#   510: K                BININT1    186
#   512: K                BININT1    80
#   514: K                BININT1    79
#   516: K                BININT1    125
#   518: K                BININT1    83
#   520: K                BININT1    82
#   522: K                BININT1    127
#   524: K                BININT1    244
#   526: K                BININT1    222
#   528: K                BININT1    225
#   530: K                BININT1    146
#   532: K                BININT1    146
#   534: K                BININT1    174
#   536: K                BININT1    146
#   538: K                BININT1    145
#   540: K                BININT1    174
#   542: K                BININT1    210
#   544: K                BININT1    210
#   546: K                BININT1    221
#   548: K                BININT1    209
#   550: K                BININT1    209
#   552: K                BININT1    221
#   554: K                BININT1    151
#   556: K                BININT1    150
#   558: K                BININT1    178
#   560: K                BININT1    154
#   562: K                BININT1    154
#   564: K                BININT1    180
#   566: K                BININT1    122
#   568: K                BININT1    121
#   570: K                BININT1    156
#   572: K                BININT1    241
#   574: K                BININT1    241
#   576: K                BININT1    245
#   578: K                BININT1    244
#   580: K                BININT1    243
#   582: K                BININT1    246
#   584: K                BININT1    127
#   586: K                BININT1    127
#   588: K                BININT1    160
#   590: K                BININT1    84
#   592: K                BININT1    83
#   594: K                BININT1    128
#   596: K                BININT1    237
#   598: K                BININT1    237
#   600: K                BININT1    242
#   602: K                BININT1    75
#   604: K                BININT1    74
#   606: K                BININT1    121
#   608: K                BININT1    252
#   610: K                BININT1    252
#   612: K                BININT1    253
#   614: K                BININT1    253
#   616: K                BININT1    253
#   618: K                BININT1    253
#   620: K                BININT1    136
#   622: K                BININT1    135
#   624: K                BININT1    166
#   626: K                BININT1    234
#   628: K                BININT1    233
#   630: K                BININT1    239
#   632: K                BININT1    108
#   634: K                BININT1    107
#   636: K                BININT1    146
#   638: K                BININT1    103
#   640: K                BININT1    102
#   642: K                BININT1    142
#   644: K                BININT1    230
#   646: K                BININT1    230
#   648: K                BININT1    236
#   650: K                BININT1    135
#   652: K                BININT1    134
#   654: K                BININT1    166
#   656: K                BININT1    138
#   658: K                BININT1    137
#   660: K                BININT1    168
#   662: K                BININT1    114
#   664: K                BININT1    113
#   666: K                BININT1    150
#   668: K                BININT1    113
#   670: K                BININT1    112
#   672: K                BININT1    149
#   674: K                BININT1    177
#   676: K                BININT1    177
#   678: K                BININT1    197
#   680: K                BININT1    176
#   682: K                BININT1    176
#   684: K                BININT1    196
#   686: K                BININT1    237
#   688: K                BININT1    237
#   690: K                BININT1    241
#   692: K                BININT1    90
#   694: K                BININT1    89
#   696: K                BININT1    132
#   698: K                BININT1    218
#   700: K                BININT1    217
#   702: K                BININT1    227
#   704: K                BININT1    222
#   706: K                BININT1    222
#   708: K                BININT1    231
#   710: K                BININT1    94
#   712: K                BININT1    93
#   714: K                BININT1    135
#   716: K                BININT1    202
#   718: K                BININT1    102
#   720: K                BININT1    115
#   722: K                BININT1    65
#   724: K                BININT1    64
#   726: K                BININT1    114
#   728: K                BININT1    235
#   730: K                BININT1    235
#   732: K                BININT1    240
#   734: K                BININT1    204
#   736: K                BININT1    203
#   738: K                BININT1    217
#   740: K                BININT1    164
#   742: K                BININT1    164
#   744: K                BININT1    187
#   746: K                BININT1    162
#   748: K                BININT1    161
#   750: K                BININT1    186
#   752: K                BININT1    81
#   754: K                BININT1    81
#   756: K                BININT1    126
#   758: K                BININT1    82
#   760: K                BININT1    81
#   762: K                BININT1    126
#   764: K                BININT1    144
#   766: K                BININT1    144
#   768: K                BININT1    173
#   770: K                BININT1    208
#   772: K                BININT1    208
#   774: K                BININT1    220
#   776: K                BININT1    208
#   778: K                BININT1    207
#   780: K                BININT1    220
#   782: K                BININT1    87
#   784: K                BININT1    86
#   786: K                BININT1    130
#   788: K                BININT1    153
#   790: K                BININT1    153
#   792: K                BININT1    179
#   794: K                BININT1    123
#   796: K                BININT1    123
#   798: K                BININT1    157
#   800: K                BININT1    242
#   802: K                BININT1    242
#   804: K                BININT1    245
#   806: K                BININT1    244
#   808: K                BININT1    244
#   810: K                BININT1    247
#   812: K                BININT1    130
#   814: K                BININT1    129
#   816: K                BININT1    162
#   818: K                BININT1    85
#   820: K                BININT1    84
#   822: K                BININT1    129
#   824: K                BININT1    251
#   826: K                BININT1    251
#   828: K                BININT1    252
#   830: K                BININT1    110
#   832: K                BININT1    109
#   834: K                BININT1    147
#   836: K                BININT1    234
#   838: K                BININT1    234
#   840: K                BININT1    240
#   842: K                BININT1    134
#   844: K                BININT1    134
#   846: K                BININT1    165
#   848: K                BININT1    220
#   850: K                BININT1    154
#   852: K                BININT1    162
#   854: K                BININT1    140
#   856: K                BININT1    139
#   858: K                BININT1    169
#   860: K                BININT1    76
#   862: K                BININT1    75
#   864: K                BININT1    122
#   866: K                BININT1    112
#   868: K                BININT1    111
#   870: K                BININT1    149
#   872: K                BININT1    175
#   874: K                BININT1    175
#   876: K                BININT1    196
#   878: K                BININT1    207
#   880: K                BININT1    207
#   882: K                BININT1    219
#   884: K                BININT1    184
#   886: K                BININT1    184
#   888: K                BININT1    202
#   890: K                BININT1    68
#   892: K                BININT1    67
#   894: K                BININT1    116
#   896: K                BININT1    102
#   898: K                BININT1    101
#   900: K                BININT1    141
#   902: K                BININT1    206
#   904: K                BININT1    206
#   906: K                BININT1    219
#   908: K                BININT1    163
#   910: K                BININT1    163
#   912: K                BININT1    187
#   914: K                BININT1    143
#   916: K                BININT1    143
#   918: K                BININT1    172
#   920: K                BININT1    226
#   922: K                BININT1    171
#   924: K                BININT1    178
#   926: K                BININT1    124
#   928: K                BININT1    124
#   930: K                BININT1    158
#   932: K                BININT1    243
#   934: K                BININT1    243
#   936: K                BININT1    246
#   938: K                BININT1    245
#   940: K                BININT1    245
#   942: K                BININT1    248
#   944: K                BININT1    130
#   946: K                BININT1    130
#   948: K                BININT1    162
#   950: K                BININT1    74
#   952: K                BININT1    73
#   954: K                BININT1    120
#   956: K                BININT1    116
#   958: K                BININT1    115
#   960: K                BININT1    152
#   962: K                BININT1    110
#   964: K                BININT1    110
#   966: K                BININT1    148
#   968: K                BININT1    133
#   970: K                BININT1    133
#   972: K                BININT1    165
#   974: K                BININT1    141
#   976: K                BININT1    140
#   978: K                BININT1    170
#   980: K                BININT1    77
#   982: K                BININT1    76
#   984: K                BININT1    123
#   986: K                BININT1    111
#   988: K                BININT1    110
#   990: K                BININT1    148
#   992: K                BININT1    175
#   994: K                BININT1    174
#   996: K                BININT1    195
#   998: K                BININT1    66
#  1000: K                BININT1    65
#  1002: K                BININT1    115
#  1004: K                BININT1    196
#  1006: K                BININT1    85
#  1008: K                BININT1    99
#  1010: K                BININT1    101
#  1012: K                BININT1    101
#  1014: K                BININT1    141
#  1016: K                BININT1    160
#  1018: K                BININT1    160
#  1020: K                BININT1    184
#  1022: K                BININT1    81
#  1024: K                BININT1    80
#  1026: K                BININT1    125
#  1028: K                BININT1    143
#  1030: K                BININT1    142
#  1032: K                BININT1    171
#  1034: K                BININT1    91
#  1036: K                BININT1    90
#  1038: K                BININT1    133
#  1040: K                BININT1    132
#  1042: K                BININT1    131
#  1044: K                BININT1    163
#  1046: K                BININT1    246
#  1048: K                BININT1    246
#  1050: K                BININT1    248
#  1052: K                BININT1    248
#  1054: K                BININT1    248
#  1056: K                BININT1    250
#  1058: K                BININT1    89
#  1060: K                BININT1    88
#  1062: K                BININT1    132
#  1064: K                BININT1    73
#  1066: K                BININT1    72
#  1068: K                BININT1    120
#  1070: K                BININT1    133
#  1072: K                BININT1    132
#  1074: K                BININT1    164
#  1076: K                BININT1    239
#  1078: K                BININT1    239
#  1080: K                BININT1    243
#  1082: K                BININT1    117
#  1084: K                BININT1    117
#  1086: K                BININT1    153
#  1088: K                BININT1    78
#  1090: K                BININT1    77
#  1092: K                BININT1    124
#  1094: K                BININT1    250
#  1096: K                BININT1    239
#  1098: K                BININT1    241
#  1100: K                BININT1    174
#  1102: K                BININT1    174
#  1104: K                BININT1    195
#  1106: K                BININT1    173
#  1108: K                BININT1    173
#  1110: K                BININT1    194
#  1112: K                BININT1    88
#  1114: K                BININT1    87
#  1116: K                BININT1    130
#  1118: K                BININT1    211
#  1120: K                BININT1    210
#  1122: K                BININT1    222
#  1124: K                BININT1    67
#  1126: K                BININT1    66
#  1128: K                BININT1    115
#  1130: K                BININT1    100
#  1132: K                BININT1    99
#  1134: K                BININT1    140
#  1136: K                BININT1    161
#  1138: K                BININT1    160
#  1140: K                BININT1    185
#  1142: K                BININT1    86
#  1144: K                BININT1    85
#  1146: K                BININT1    129
#  1148: K                BININT1    235
#  1150: K                BININT1    225
#  1152: K                BININT1    231
#  1154: K                BININT1    136
#  1156: K                BININT1    136
#  1158: K                BININT1    136
#  1160: K                BININT1    137
#  1162: K                BININT1    137
#  1164: K                BININT1    137
#  1166: K                BININT1    138
#  1168: K                BININT1    138
#  1170: K                BININT1    138
#  1172: K                BININT1    139
#  1174: K                BININT1    139
#  1176: K                BININT1    139
#  1178: K                BININT1    140
#  1180: K                BININT1    140
#  1182: K                BININT1    140
#  1184: K                BININT1    141
#  1186: K                BININT1    141
#  1188: K                BININT1    141
#  1190: K                BININT1    142
#  1192: K                BININT1    142
#  1194: K                BININT1    142
#  1196: K                BININT1    143
#  1198: K                BININT1    143
#  1200: K                BININT1    143
#  1202: K                BININT1    144
#  1204: K                BININT1    144
#  1206: K                BININT1    144
#  1208: K                BININT1    145
#  1210: K                BININT1    145
#  1212: K                BININT1    145
#  1214: K                BININT1    146
#  1216: K                BININT1    146
#  1218: K                BININT1    146
#  1220: K                BININT1    147
#  1222: K                BININT1    147
#  1224: K                BININT1    147
#  1226: K                BININT1    148
#  1228: K                BININT1    148
#  1230: K                BININT1    148
#  1232: K                BININT1    149
#  1234: K                BININT1    149
#  1236: K                BININT1    149
#  1238: K                BININT1    150
#  1240: K                BININT1    150
#  1242: K                BININT1    150
#  1244: K                BININT1    151
#  1246: K                BININT1    151
#  1248: K                BININT1    151
#  1250: K                BININT1    152
#  1252: K                BININT1    152
#  1254: K                BININT1    152
#  1256: K                BININT1    153
#  1258: K                BININT1    153
#  1260: K                BININT1    153
#  1262: K                BININT1    154
#  1264: K                BININT1    154
#  1266: K                BININT1    154
#  1268: K                BININT1    155
#  1270: K                BININT1    155
#  1272: K                BININT1    155
#  1274: K                BININT1    156
#  1276: K                BININT1    156
#  1278: K                BININT1    156
#  1280: K                BININT1    157
#  1282: K                BININT1    157
#  1284: K                BININT1    157
#  1286: K                BININT1    158
#  1288: K                BININT1    158
#  1290: K                BININT1    158
#  1292: K                BININT1    159
#  1294: K                BININT1    159
#  1296: K                BININT1    159
#  1298: K                BININT1    160
#  1300: K                BININT1    160
#  1302: K                BININT1    160
#  1304: K                BININT1    161
#  1306: K                BININT1    161
#  1308: K                BININT1    161
#  1310: K                BININT1    162
#  1312: K                BININT1    162
#  1314: K                BININT1    162
#  1316: K                BININT1    163
#  1318: K                BININT1    163
#  1320: K                BININT1    163
#  1322: K                BININT1    164
#  1324: K                BININT1    164
#  1326: K                BININT1    164
#  1328: K                BININT1    165
#  1330: K                BININT1    165
#  1332: K                BININT1    165
#  1334: K                BININT1    166
#  1336: K                BININT1    166
#  1338: K                BININT1    166
#  1340: K                BININT1    167
#  1342: K                BININT1    167
#  1344: K                BININT1    167
#  1346: K                BININT1    168
#  1348: K                BININT1    168
#  1350: K                BININT1    168
#  1352: K                BININT1    169
#  1354: K                BININT1    169
#  1356: K                BININT1    169
#  1358: K                BININT1    170
#  1360: K                BININT1    170
#  1362: K                BININT1    170
#  1364: K                BININT1    171
#  1366: K                BININT1    171
#  1368: K                BININT1    171
#  1370: K                BININT1    172
#  1372: K                BININT1    172
#  1374: K                BININT1    172
#  1376: K                BININT1    173
#  1378: K                BININT1    173
#  1380: K                BININT1    173
#  1382: K                BININT1    174
#  1384: K                BININT1    174
#  1386: K                BININT1    174
#  1388: K                BININT1    175
#  1390: K                BININT1    175
#  1392: K                BININT1    175
#  1394: K                BININT1    176
#  1396: K                BININT1    176
#  1398: K                BININT1    176
#  1400: K                BININT1    177
#  1402: K                BININT1    177
#  1404: K                BININT1    177
#  1406: K                BININT1    178
#  1408: K                BININT1    178
#  1410: K                BININT1    178
#  1412: K                BININT1    179
#  1414: K                BININT1    179
#  1416: K                BININT1    179
#  1418: K                BININT1    180
#  1420: K                BININT1    180
#  1422: K                BININT1    180
#  1424: K                BININT1    181
#  1426: K                BININT1    181
#  1428: K                BININT1    181
#  1430: K                BININT1    182
#  1432: K                BININT1    182
#  1434: K                BININT1    182
#  1436: K                BININT1    183
#  1438: K                BININT1    183
#  1440: K                BININT1    183
#  1442: K                BININT1    184
#  1444: K                BININT1    184
#  1446: K                BININT1    184
#  1448: K                BININT1    185
#  1450: K                BININT1    185
#  1452: K                BININT1    185
#  1454: K                BININT1    186
#  1456: K                BININT1    186
#  1458: K                BININT1    186
#  1460: K                BININT1    187
#  1462: K                BININT1    187
#  1464: K                BININT1    187
#  1466: K                BININT1    188
#  1468: K                BININT1    188
#  1470: K                BININT1    188
#  1472: K                BININT1    189
#  1474: K                BININT1    189
#  1476: K                BININT1    189
#  1478: K                BININT1    190
#  1480: K                BININT1    190
#  1482: K                BININT1    190
#  1484: K                BININT1    191
#  1486: K                BININT1    191
#  1488: K                BININT1    191
#  1490: K                BININT1    192
#  1492: K                BININT1    192
#  1494: K                BININT1    192
#  1496: K                BININT1    193
#  1498: K                BININT1    193
#  1500: K                BININT1    193
#  1502: K                BININT1    194
#  1504: K                BININT1    194
#  1506: K                BININT1    194
#  1508: K                BININT1    195
#  1510: K                BININT1    195
#  1512: K                BININT1    195
#  1514: K                BININT1    196
#  1516: K                BININT1    196
#  1518: K                BININT1    196
#  1520: K                BININT1    197
#  1522: K                BININT1    197
#  1524: K                BININT1    197
#  1526: K                BININT1    198
#  1528: K                BININT1    198
#  1530: K                BININT1    198
#  1532: K                BININT1    199
#  1534: K                BININT1    199
#  1536: K                BININT1    199
#  1538: K                BININT1    200
#  1540: K                BININT1    200
#  1542: K                BININT1    200
#  1544: K                BININT1    201
#  1546: K                BININT1    201
#  1548: K                BININT1    201
#  1550: K                BININT1    202
#  1552: K                BININT1    202
#  1554: K                BININT1    202
#  1556: K                BININT1    203
#  1558: K                BININT1    203
#  1560: K                BININT1    203
#  1562: K                BININT1    204
#  1564: K                BININT1    204
#  1566: K                BININT1    204
#  1568: K                BININT1    205
#  1570: K                BININT1    205
#  1572: K                BININT1    205
#  1574: K                BININT1    206
#  1576: K                BININT1    206
#  1578: K                BININT1    206
#  1580: K                BININT1    207
#  1582: K                BININT1    207
#  1584: K                BININT1    207
#  1586: K                BININT1    208
#  1588: K                BININT1    208
#  1590: K                BININT1    208
#  1592: K                BININT1    209
#  1594: K                BININT1    209
#  1596: K                BININT1    209
#  1598: K                BININT1    210
#  1600: K                BININT1    210
#  1602: K                BININT1    210
#  1604: K                BININT1    211
#  1606: K                BININT1    211
#  1608: K                BININT1    211
#  1610: K                BININT1    212
#  1612: K                BININT1    212
#  1614: K                BININT1    212
#  1616: K                BININT1    213
#  1618: K                BININT1    213
#  1620: K                BININT1    213
#  1622: K                BININT1    214
#  1624: K                BININT1    214
#  1626: K                BININT1    214
#  1628: K                BININT1    215
#  1630: K                BININT1    215
#  1632: K                BININT1    215
#  1634: K                BININT1    216
#  1636: K                BININT1    216
#  1638: K                BININT1    216
#  1640: K                BININT1    217
#  1642: K                BININT1    217
#  1644: K                BININT1    217
#  1646: K                BININT1    218
#  1648: K                BININT1    218
#  1650: K                BININT1    218
#  1652: K                BININT1    219
#  1654: K                BININT1    219
#  1656: K                BININT1    219
#  1658: K                BININT1    220
#  1660: K                BININT1    220
#  1662: K                BININT1    220
#  1664: K                BININT1    221
#  1666: K                BININT1    221
#  1668: K                BININT1    221
#  1670: K                BININT1    222
#  1672: K                BININT1    222
#  1674: K                BININT1    222
#  1676: K                BININT1    223
#  1678: K                BININT1    223
#  1680: K                BININT1    223
#  1682: K                BININT1    224
#  1684: K                BININT1    224
#  1686: K                BININT1    224
#  1688: K                BININT1    225
#  1690: K                BININT1    225
#  1692: K                BININT1    225
#  1694: K                BININT1    226
#  1696: K                BININT1    226
#  1698: K                BININT1    226
#  1700: K                BININT1    227
#  1702: K                BININT1    227
#  1704: K                BININT1    227
#  1706: K                BININT1    228
#  1708: K                BININT1    228
#  1710: K                BININT1    228
#  1712: K                BININT1    229
#  1714: K                BININT1    229
#  1716: K                BININT1    229
#  1718: K                BININT1    230
#  1720: K                BININT1    230
#  1722: K                BININT1    230
#  1724: K                BININT1    231
#  1726: K                BININT1    231
#  1728: K                BININT1    231
#  1730: K                BININT1    232
#  1732: K                BININT1    232
#  1734: K                BININT1    232
#  1736: K                BININT1    233
#  1738: K                BININT1    233
#  1740: K                BININT1    233
#  1742: K                BININT1    234
#  1744: K                BININT1    234
#  1746: K                BININT1    234
#  1748: K                BININT1    235
#  1750: K                BININT1    235
#  1752: K                BININT1    235
#  1754: K                BININT1    236
#  1756: K                BININT1    236
#  1758: K                BININT1    236
#  1760: K                BININT1    237
#  1762: K                BININT1    237
#  1764: K                BININT1    237
#  1766: K                BININT1    238
#  1768: K                BININT1    238
#  1770: K                BININT1    238
#  1772: K                BININT1    239
#  1774: K                BININT1    239
#  1776: K                BININT1    239
#  1778: K                BININT1    240
#  1780: K                BININT1    240
#  1782: K                BININT1    240
#  1784: K                BININT1    241
#  1786: K                BININT1    241
#  1788: K                BININT1    241
#  1790: K                BININT1    242
#  1792: K                BININT1    242
#  1794: K                BININT1    242
#  1796: K                BININT1    243
#  1798: K                BININT1    243
#  1800: K                BININT1    243
#  1802: K                BININT1    244
#  1804: K                BININT1    244
#  1806: K                BININT1    244
#  1808: K                BININT1    245
#  1810: K                BININT1    245
#  1812: K                BININT1    245
#  1814: K                BININT1    246
#  1816: K                BININT1    246
#  1818: K                BININT1    246
#  1820: K                BININT1    247
#  1822: K                BININT1    247
#  1824: K                BININT1    247
#  1826: K                BININT1    248
#  1828: K                BININT1    248
#  1830: K                BININT1    248
#  1832: K                BININT1    249
#  1834: K                BININT1    249
#  1836: K                BININT1    249
#  1838: K                BININT1    250
#  1840: K                BININT1    250
#  1842: K                BININT1    250
#  1844: K                BININT1    251
#  1846: K                BININT1    251
#  1848: K                BININT1    251
#  1850: K                BININT1    252
#  1852: K                BININT1    252
#  1854: K                BININT1    252
#  1856: K                BININT1    253
#  1858: K                BININT1    253
#  1860: K                BININT1    253
#  1862: K                BININT1    254
#  1864: K                BININT1    254
#  1866: K                BININT1    254
#  1868: K                BININT1    255
#  1870: K                BININT1    255
#  1872: K                BININT1    255
#  1874: e                APPENDS    (MARK at 337)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-410b2f975d92> in <module>()
# ----> 1 pickletools.dis(data[:1875])
#
# /usr/lib/python3.7/pickletools.py in dis(pickle, out, memo, indentlevel, annotate)
#    2368     errormsg = None
#    2369     annocol = annotate  # column hint for annotations
# -> 2370     for opcode, arg, pos in genops(pickle):
#    2371         if pos is not None:
#    2372             print("%5d:" % pos, end=' ', file=out)
#
# /usr/lib/python3.7/pickletools.py in _genops(data, yield_end_pos)
#    2203         if opcode is None:
#    2204             if code == b"":
# -> 2205                 raise ValueError("pickle exhausted before seeing STOP")
#    2206             else:
#    2207                 raise ValueError("at position %s, opcode %r unknown" % (
#
# ValueError: pickle exhausted before seeing STOP

# %%
entryname = data[data.find(b"http"):data.find(b"cPIL")]
remainder_data = data[data.find(b"q\x01cPIL"):]
print(remainder_data[:remainder_data.find(b"http")+6][-10:])
pickle.loads(remainder_data[:remainder_data.find(b"http")] + b"q.")
print(entryname)
#data = f.read(int(5.369e9))
#fr_en_images = pickle.loads(data)
# Out:
# b'%\x00\x00\x00http:/'
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-14-0bc6bf7280da> in <module>()
#       2 remainder_data = data[data.find(b"q\x01cPIL"):]
#       3 print(remainder_data[:remainder_data.find(b"http")+6][-10:])
# ----> 4 pickle.loads(remainder_data[:remainder_data.find(b"http")] + b"q.")
#       5 print(entryname)
#       6 #data = f.read(int(5.369e9))
#
# UnpicklingError: unpickling stack underflow

# %%
# now let's check if the every entry in our images pickle file is in our ent2id dict:
num_missing = 0
for linkname in fr_en_images.keys():
    if linkname not in ent2id_dict:
        num_missing += 1
print(f"Missing {num_missing} entries")
