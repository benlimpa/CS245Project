# %% [markdown]
# # HOW TO RUN THIS FILE
# 1. edit the ROOT_PATH variable to match the path from your google drive to the eva shared folder
# 2. make sure that the runtime type is set to GPU. the code requires CUDA to work. (you can set it to CPU only mode, but it's about 10x slower)

# %%
# !nvidia-smi
# Out:
# Wed Dec  1 01:49:00 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import sys
# EDIT THIS VARIABLE:
ROOT_PATH = "/content/drive/MyDrive/CS245_Project_Shared/eva"
SRC_PATH = os.path.join(ROOT_PATH, "src")
sys.path.append(SRC_PATH)
from run_dbp15k import *

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--file_dir", type=str, default="data/DBP15K/zh_en", required=False, help="input dataset file directory, ('data/DBP15K/zh_en', 'data/DWY100K/dbp_wd')")
parser.add_argument("--rate", type=float, default=0.3, help="training set rate")

parser.add_argument("--cuda", action="store_true", default=True, help="whether to use cuda or not")
parser.add_argument("--seed", type=int, default=2021, help="random seed")
parser.add_argument("--epochs", type=int, default=1000, help="number of epochs to train")
parser.add_argument("--check_point", type=int, default=100, help="check point")
parser.add_argument("--hidden_units", type=str, default="128,128,128", help="hidden units in each hidden layer(including in_dim and out_dim), splitted with comma")
parser.add_argument("--heads", type=str, default="2,2", help="heads in each gat layer, splitted with comma")
parser.add_argument("--instance_normalization", action="store_true", default=False, help="enable instance normalization")
parser.add_argument("--lr", type=float, default=0.005, help="initial learning rate")
parser.add_argument("--weight_decay", type=float, default=0, help="weight decay (L2 loss on parameters)")
parser.add_argument("--dropout", type=float, default=0.0, help="dropout rate for layers")
parser.add_argument("--attn_dropout", type=float, default=0.0, help="dropout rate for gat layers")
parser.add_argument("--dist", type=int, default=2, help="L1 distance or L2 distance. ('1', '2')")
parser.add_argument("--csls", action="store_true", default=False, help="use CSLS for inference")
parser.add_argument("--csls_k", type=int, default=10, help="top k for csls")
parser.add_argument("--il", action="store_true", default=False, help="Iterative learning?")
parser.add_argument("--semi_learn_step", type=int, default=10, help="If IL, what's the update step?")
parser.add_argument("--il_start", type=int, default=500, help="If Il, when to start?")
parser.add_argument("--bsize", type=int, default=7500, help="batch size")
parser.add_argument("--unsup", action="store_true", default=False)
parser.add_argument("--unsup_k", type=int, default=1000, help="|visual seed|")
#parser.add_argument("--long_tail_analysis", action="store_true", default=False)
parser.add_argument("--lta_split", type=int, default=0, help="split in {0,1,2,3,|splits|-1}")

args = argparse.Namespace(
    file_dir=os.path.join(ROOT_PATH, "data/DBP15K/fr_en"),
    rate=0.3,
    lr=0.0005,
    epochs=50, #1000 originally
    hiden_units="400,400,200",
    check_point=50,
    bsize=7500,
    il=False, # True originally
    il_start=500,
    semi_learn_step=5,
    csls=True,
    csls_k=3,
    seed=0,
)
args = parser.parse_args(args=[], namespace=args)
main(args, root_path=ROOT_PATH)
# Out:
# loading raw data...
# 70.69% entities have images
# image feature shape: torch.Size([39654, 2048])
# #left entity : 19661, #right entity: 19993
# #left entity not in train set: 15161, #right entity not in train set: 15493
# relation feature shape: torch.Size([39654, 1000])
# attribute feature shape: torch.Size([39654, 1000])
# -----dataset summary-----
# dataset:	 /content/drive/MyDrive/CS245_Project_Shared/eva/data/DBP15K/fr_en
# triple num:	 221720
# entity num:	 39654
# relation num:	 2111
# train ill num:	 4500 	test ill num:	 10500
# -------------------------
# getting a sparse tensor r_adj...
# GCN model details:
# GCN(
#   (gc1): GraphConvolution (128 -> 128)
#   (gc2): GraphConvolution (128 -> 128)
# )
# optimiser details:
# AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0005
#     weight_decay: 0.01
# )
# [start training...]
# [epoch 0] loss_all: -6.590077, time: 0.3505 s
# [epoch 1] loss_all: -8.100548, time: 0.2335 s
# [epoch 2] loss_all: -9.315067, time: 0.2292 s
# [epoch 3] loss_all: -10.348263, time: 0.2272 s
# [epoch 4] loss_all: -11.224287, time: 0.2288 s
# [epoch 5] loss_all: -11.967997, time: 0.2291 s
# [epoch 6] loss_all: -12.599730, time: 0.2328 s
# [epoch 7] loss_all: -13.139867, time: 0.2268 s
# [epoch 8] loss_all: -13.605021, time: 0.2275 s
# [epoch 9] loss_all: -14.006905, time: 0.2277 s
# [epoch 10] loss_all: -14.356096, time: 0.2365 s
# [epoch 11] loss_all: -14.661791, time: 0.2310 s
# [epoch 12] loss_all: -14.931519, time: 0.2293 s
# [epoch 13] loss_all: -15.171429, time: 0.2295 s
# [epoch 14] loss_all: -15.386596, time: 0.2368 s
# [epoch 15] loss_all: -15.581220, time: 0.2253 s
# [epoch 16] loss_all: -15.758654, time: 0.2301 s
# [epoch 17] loss_all: -15.921640, time: 0.2289 s
# [epoch 18] loss_all: -16.072613, time: 0.2286 s
# [epoch 19] loss_all: -16.213133, time: 0.2297 s
# [epoch 20] loss_all: -16.344273, time: 0.2319 s
# [epoch 21] loss_all: -16.466833, time: 0.2281 s
# [epoch 22] loss_all: -16.581314, time: 0.2275 s
# [epoch 23] loss_all: -16.687992, time: 0.2293 s
# [epoch 24] loss_all: -16.786980, time: 0.2312 s
# [epoch 25] loss_all: -16.878355, time: 0.2254 s
# [epoch 26] loss_all: -16.962233, time: 0.2274 s
# [epoch 27] loss_all: -17.038870, time: 0.2271 s
# [epoch 28] loss_all: -17.108702, time: 0.2315 s
# [epoch 29] loss_all: -17.172285, time: 0.2252 s
# [epoch 30] loss_all: -17.230354, time: 0.2290 s
# [epoch 31] loss_all: -17.283842, time: 0.2301 s
# [epoch 32] loss_all: -17.333662, time: 0.2271 s
# [epoch 33] loss_all: -17.380444, time: 0.2266 s
# [epoch 34] loss_all: -17.424520, time: 0.2340 s
# [epoch 35] loss_all: -17.466045, time: 0.2246 s
# [epoch 36] loss_all: -17.505186, time: 0.2270 s
# [epoch 37] loss_all: -17.542261, time: 0.2284 s
# [epoch 38] loss_all: -17.577635, time: 0.2324 s
# [epoch 39] loss_all: -17.611616, time: 0.2252 s
# [epoch 40] loss_all: -17.644423, time: 0.2334 s
# [epoch 41] loss_all: -17.676197, time: 0.2260 s
# [epoch 42] loss_all: -17.707096, time: 0.2262 s
# [epoch 43] loss_all: -17.737429, time: 0.2275 s
# [epoch 44] loss_all: -17.767569, time: 0.2268 s
# [epoch 45] loss_all: -17.797804, time: 0.2313 s
# [epoch 46] loss_all: -17.828337, time: 0.2259 s
# [epoch 47] loss_all: -17.859383, time: 0.2279 s
# [epoch 48] loss_all: -17.891022, time: 0.2301 s
# [epoch 49] loss_all: -17.922789, time: 0.2293 s
#
# [epoch 49] checkpoint!
# normalised weights: tensor([0.2526, 0.2477, 0.2467, 0.2530], device='cuda:0')
# Saving final embeddings
# l2r: acc of top [1, 10, 50] = [0.1588 0.3899 0.6066], mr = 472.792, mrr = 0.235, time = 10.7412 s
# r2l: acc of top [1, 10, 50] = [0.1528 0.3938 0.6022], mr = 477.970, mrr = 0.233, time = 10.7418 s
#
# [optimization finished!]
# [total time elapsed: 25.4231 s]
# (array([0.1588, 0.3899, 0.6066], dtype=float32),
#  array([0.1528, 0.3938, 0.6022], dtype=float32),
#  472.7920952380952,
#  477.9702857142857,
#  0.2349791641446913,
#  0.23288773532230558)

# %% [markdown]
# # Loading Embeddings and Calculating Similarity matrix

# %%
# load the final embeddings after 50 epochs from google drive
# make sure you change root path and file_dir to the path from your google drive
final_embed = torch.load(os.path.join(ROOT_PATH, "final_embed_49.pt"))
ent2id_dict, ills, triples, r_hs, r_ts, ids = read_raw_data(args.file_dir, [1,2])
# split the dataset into the test set
test_ill_ = ills[int(len(ills) // 1 * args.rate):]
test_ill = np.array(test_ill_, dtype=np.int32)
# split the test set into elements in the left graph and right graph
test_left = torch.LongTensor(test_ill[:, 0].squeeze())
test_right = torch.LongTensor(test_ill[:, 1].squeeze())

# split the final embeddings into the two graphs (left and right)
final_embed_left = final_embed[test_left]
final_embed_right = final_embed[test_right]
# Out:
# loading raw data...

# %%
# this is a NxD array where N is the number of entities and D is the length of the embedding
final_embed_left.shape
# Out:
# torch.Size([10500, 528])

# %%
final_embed_right.shape
# Out:
# torch.Size([10500, 528])

# %% [markdown]
# # Using AutoEncoder
# Dimensionality reduction of embeddings from EVA using AutoEncoder.

# %%
import numpy as np
import torch
import argparse
from tqdm import tqdm
from sklearn.datasets import load_wine
from sklearn import preprocessing
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.cluster import normalized_mutual_info_score
from torch import nn, optim

# %%
def calc_accuracy(embeddings):
    distance = pairwise_distances(embeddings[test_left], embeddings[test_right])
    print(distance.shape)
    distance = 1 - csls_sim(1 - distance, 3)
    test_left_np = test_left.cpu().numpy()
    test_right_np = test_right.cpu().numpy()
    acc_l2r = 0
    acc_r2l = 0
    for idx in range(test_left.shape[0]):
        values, indices = torch.sort(distance[idx, :], descending=False)
        rank = (indices == idx).nonzero().squeeze().item()
        if rank < 1:
            acc_l2r += 1
    for idx in range(test_right.shape[0]):
        _, indices = torch.sort(distance[:, idx], descending=False)
        rank = (indices == idx).nonzero().squeeze().item()
        if rank < 1:
            acc_r2l += 1
    acc_l2r = round(acc_l2r / test_left.size(0), 4)
    acc_r2l = round(acc_r2l / test_right.size(0), 4)
    return acc_l2r, acc_r2l
acc_l2r, acc_r2l = calc_accuracy(final_embed)
print(f"acc: {acc_l2r}, {acc_r2l}")
print(final_embed.shape)
# Out:
# torch.Size([10500, 10500])
# acc: 0.2325, 0.231
# torch.Size([39654, 528])

# %%
class autoencoder(nn.Module):
    def __init__(self):
        super(autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(528, 128),
            nn.Sigmoid())
            #nn.Linear(128, 64))
            #nn.ReLU(True), 
            #nn.Linear(64, 12))
        self.decoder = nn.Sequential(
            #nn.Linear(12, 64),
            #nn.ReLU(True),
            #nn.Linear(64, 128),
            #nn.ReLU(True),
            nn.Linear(128, 528), nn.ReLU(True))
        self.encoder.register_forward_hook(self.save_latent())

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
    
    def save_latent(self):
        def hook(module, input, output):
            self.latent = output
        return hook


model = autoencoder().cuda()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(
    model.parameters(), lr=0.001, weight_decay=1e-5)

num_epochs = 100
for epoch in range(num_epochs):
    x = final_embed.cuda()
    print(final_embed.shape)
    # ===================forward=====================
    output = model(x)
    loss = criterion(output, x)
    # ===================backward====================
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    # ===================log========================
    print('epoch [{}/{}], loss:{:.4f}'
          .format(epoch + 1, num_epochs, loss.data))
    print(model.latent.shape)
    acc_l2r, acc_r2l = calc_accuracy(model.latent)
    print(f"acc: {acc_l2r}, {acc_r2l}")
# Out:
# torch.Size([39654, 528])
# epoch [1/100], loss:0.0426
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1845, 0.1827
# torch.Size([39654, 528])
# epoch [2/100], loss:0.0298
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1867, 0.188
# torch.Size([39654, 528])
# epoch [3/100], loss:0.0203
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1856, 0.1863
# torch.Size([39654, 528])
# epoch [4/100], loss:0.0137
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1857, 0.1854
# torch.Size([39654, 528])
# epoch [5/100], loss:0.0092
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1802, 0.182
# torch.Size([39654, 528])
# epoch [6/100], loss:0.0062
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1729, 0.1782
# torch.Size([39654, 528])
# epoch [7/100], loss:0.0044
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1703, 0.1721
# torch.Size([39654, 528])
# epoch [8/100], loss:0.0032
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1635, 0.1678
# torch.Size([39654, 528])
# epoch [9/100], loss:0.0026
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.161, 0.1618
# torch.Size([39654, 528])
# epoch [10/100], loss:0.0022
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1543, 0.1607
# torch.Size([39654, 528])
# epoch [11/100], loss:0.0020
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.151, 0.1538
# torch.Size([39654, 528])
# epoch [12/100], loss:0.0019
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.149, 0.1497
# torch.Size([39654, 528])
# epoch [13/100], loss:0.0019
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1455, 0.1473
# torch.Size([39654, 528])
# epoch [14/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1461, 0.144
# torch.Size([39654, 528])
# epoch [15/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1406, 0.1424
# torch.Size([39654, 528])
# epoch [16/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1416, 0.1403
# torch.Size([39654, 528])
# epoch [17/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.138, 0.1379
# torch.Size([39654, 528])
# epoch [18/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.137, 0.1357
# torch.Size([39654, 528])
# epoch [19/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.133, 0.1346
# torch.Size([39654, 528])
# epoch [20/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.133, 0.1327
# torch.Size([39654, 528])
# epoch [21/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.131, 0.1307
# torch.Size([39654, 528])
# epoch [22/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1296, 0.1291
# torch.Size([39654, 528])
# epoch [23/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1274, 0.1278
# torch.Size([39654, 528])
# epoch [24/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1267, 0.1259
# torch.Size([39654, 528])
# epoch [25/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1279, 0.1272
# torch.Size([39654, 528])
# epoch [26/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1249, 0.1256
# torch.Size([39654, 528])
# epoch [27/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1259, 0.1244
# torch.Size([39654, 528])
# epoch [28/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.124, 0.123
# torch.Size([39654, 528])
# epoch [29/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1241, 0.1212
# torch.Size([39654, 528])
# epoch [30/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1222, 0.1207
# torch.Size([39654, 528])
# epoch [31/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1222, 0.1203
# torch.Size([39654, 528])
# epoch [32/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1211, 0.1206
# torch.Size([39654, 528])
# epoch [33/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1198, 0.1184
# torch.Size([39654, 528])
# epoch [34/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1211, 0.1185
# torch.Size([39654, 528])
# epoch [35/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1207, 0.1181
# torch.Size([39654, 528])
# epoch [36/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1193, 0.1174
# torch.Size([39654, 528])
# epoch [37/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1193, 0.1187
# torch.Size([39654, 528])
# epoch [38/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.117, 0.1165
# torch.Size([39654, 528])
# epoch [39/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1175, 0.1162
# torch.Size([39654, 528])
# epoch [40/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1177, 0.1151
# torch.Size([39654, 528])
# epoch [41/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1171, 0.1146
# torch.Size([39654, 528])
# epoch [42/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1162, 0.1139
# torch.Size([39654, 528])
# epoch [43/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1161, 0.1139
# torch.Size([39654, 528])
# epoch [44/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.117, 0.1142
# torch.Size([39654, 528])
# epoch [45/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1163, 0.1129
# torch.Size([39654, 528])
# epoch [46/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1152, 0.1144
# torch.Size([39654, 528])
# epoch [47/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1141, 0.1115
# torch.Size([39654, 528])
# epoch [48/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1141, 0.1117
# torch.Size([39654, 528])
# epoch [49/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.115, 0.1128
# torch.Size([39654, 528])
# epoch [50/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1149, 0.1109
# torch.Size([39654, 528])
# epoch [51/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.113, 0.1109
# torch.Size([39654, 528])
# epoch [52/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.111, 0.1109
# torch.Size([39654, 528])
# epoch [53/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1132, 0.1101
# torch.Size([39654, 528])
# epoch [54/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1151, 0.1115
# torch.Size([39654, 528])
# epoch [55/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1127, 0.1101
# torch.Size([39654, 528])
# epoch [56/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.113, 0.1096
# torch.Size([39654, 528])
# epoch [57/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1128, 0.1083
# torch.Size([39654, 528])
# epoch [58/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1126, 0.1115
# torch.Size([39654, 528])
# epoch [59/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1118, 0.109
# torch.Size([39654, 528])
# epoch [60/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1103, 0.107
# torch.Size([39654, 528])
# epoch [61/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.111, 0.1094
# torch.Size([39654, 528])
# epoch [62/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1103, 0.1089
# torch.Size([39654, 528])
# epoch [63/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1104, 0.1079
# torch.Size([39654, 528])
# epoch [64/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1123, 0.1083
# torch.Size([39654, 528])
# epoch [65/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1108, 0.1062
# torch.Size([39654, 528])
# epoch [66/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.111, 0.1077
# torch.Size([39654, 528])
# epoch [67/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1093, 0.1063
# torch.Size([39654, 528])
# epoch [68/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1104, 0.1072
# torch.Size([39654, 528])
# epoch [69/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1111, 0.1066
# torch.Size([39654, 528])
# epoch [70/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1087, 0.108
# torch.Size([39654, 528])
# epoch [71/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1096, 0.1074
# torch.Size([39654, 528])
# epoch [72/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1096, 0.1063
# torch.Size([39654, 528])
# epoch [73/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1109, 0.105
# torch.Size([39654, 528])
# epoch [74/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1102, 0.109
# torch.Size([39654, 528])
# epoch [75/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1108, 0.1057
# torch.Size([39654, 528])
# epoch [76/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1094, 0.1059
# torch.Size([39654, 528])
# epoch [77/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.109, 0.1041
# torch.Size([39654, 528])
# epoch [78/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.109, 0.1042
# torch.Size([39654, 528])
# epoch [79/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1078, 0.1057
# torch.Size([39654, 528])
# epoch [80/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.108, 0.1064
# torch.Size([39654, 528])
# epoch [81/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1069, 0.1058
# torch.Size([39654, 528])
# epoch [82/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1075, 0.1049
# torch.Size([39654, 528])
# epoch [83/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1095, 0.1066
# torch.Size([39654, 528])
# epoch [84/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1106, 0.1071
# torch.Size([39654, 528])
# epoch [85/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1102, 0.1042
# torch.Size([39654, 528])
# epoch [86/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1083, 0.101
# torch.Size([39654, 528])
# epoch [87/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.108, 0.1025
# torch.Size([39654, 528])
# epoch [88/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1066, 0.1032
# torch.Size([39654, 528])
# epoch [89/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1051, 0.1039
# torch.Size([39654, 528])
# epoch [90/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1064, 0.1046
# torch.Size([39654, 528])
# epoch [91/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1081, 0.1039
# torch.Size([39654, 528])
# epoch [92/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1044, 0.1027
# torch.Size([39654, 528])
# epoch [93/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1066, 0.103
# torch.Size([39654, 528])
# epoch [94/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1061, 0.1034
# torch.Size([39654, 528])
# epoch [95/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1077, 0.1038
# torch.Size([39654, 528])
# epoch [96/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1068, 0.103
# torch.Size([39654, 528])
# epoch [97/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.104, 0.1016
# torch.Size([39654, 528])
# epoch [98/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1061, 0.1031
# torch.Size([39654, 528])
# epoch [99/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1053, 0.1022
# torch.Size([39654, 528])
# epoch [100/100], loss:0.0018
# torch.Size([39654, 128])
# torch.Size([10500, 10500])
# acc: 0.1067, 0.1033

# %% [markdown]
# # Clustering with GraphEncoder
# ## -- SCRAPPED FOR NOW --

# %%
# convert the pytorch tensors to numpy arrays
X = final_embed_left.cpu().detach().numpy()
Y = final_embed_right.cpu().detach().numpy()
print(type(X))
print(X.shape)
print(type(Y))
print(Y.shape)
# Out:
# <class 'numpy.ndarray'>
# (10500, 528)
# <class 'numpy.ndarray'>
# (10500, 528)

# %%
# EDIT THIS VARIABLE
# %cd /content/drive/MyDrive/CS245_Project_Shared/eva/src/
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1TNHdJkAXnDAdPZ4uzztu_RrLScIxYZuJ/CS245 Project Shared/eva/src
# eva.py	   Load.py   models.py	  run_dbp15k.py  utils.py
# layers.py  model.py  __pycache__  run_dwy15k.py

# %%
import numpy as np
import torch
import argparse
from tqdm import tqdm
from sklearn.datasets import load_wine
from sklearn import preprocessing
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.cluster import normalized_mutual_info_score
from torch import nn, optim

from model import GraphEncoder

# %%
parser = argparse.ArgumentParser()
#parser.add_argument('--dataset', type=str, default='wine', help='Dataset to use')
parser.add_argument('-l', '--layers', nargs='+', type=int, default=[128, 64, 128], help='Sparsity Penalty Parameter')
parser.add_argument('-b', '--beta', type=float, default=0.01, help='Sparsity Penalty Parameter')
parser.add_argument('-p', '--rho', type=float, default=0.5, help='Prior rho')
parser.add_argument('-lr', type=float, default=0.01, help='Learning Rate')
parser.add_argument('-epoch', type=int, default=200, help='Number of Training Epochs')
parser.add_argument('-device', type=str, default='gpu', help='Train on GPU or CPU')

args = argparse.Namespace(
    l = [128, 64, 128],
    b = 0.01,
    p = 0.5,
    lr = 0.01,
    epoch = 7,
    device = 'gpu'
)
args = parser.parse_args(args=[], namespace=args)

device = torch.device('cuda' if args.device == 'gpu' else 'cpu')

# number of clusters = number of entities in X
k = Y.shape[0]

def main():

    # Obtain Similarity matrix
    S = cosine_similarity(X, Y)

    D = np.diag(1.0 / np.sqrt(S.sum(axis=1)))
    X_train = torch.tensor(D.dot(S).dot(D)).float().to(device)

    layers = [len(X_train)] + args.layers + [len(X_train)]

    model = GraphEncoder(layers, k).to(device)
    optimizer = optim.Adam(model.parameters(), lr=args.lr)

    with tqdm(total=args.epoch) as tq:
        for epoch in range(1, args.epoch + 1):
            optimizer.zero_grad()
            X_hat = model(X_train)
            loss = model.loss(X_hat, X_train, args.beta, args.rho)

            #pred_labels = model.get_cluster()
            #print(pred_labels.shape)
            #print(type(pred_labels))

            #true_labels =  np.arange(1, Y.shape[0] + 1)

            #nmi = normalized_mutual_info_score(pred_labels, true_labels, average_method='arithmetic')

            loss.backward()
            optimizer.step()

            tq.set_postfix(loss='{:.3f}'.format(loss), nmi='{:.3f}'.format(nmi))
            tq.update()
        print(model.get_cluster())


if __name__ == '__main__':
    main()
# Out:
#   1%|          | 1/100 [11:03<18:14:10, 663.14s/it, loss=0.257, nmi=1.000]
# (10500,)
# <class 'numpy.ndarray'>
#   2%|▏         | 2/100 [22:08<18:04:50, 664.18s/it, loss=0.142, nmi=1.000]
# (10500,)
# <class 'numpy.ndarray'>
#   3%|▎         | 3/100 [33:08<17:51:21, 662.70s/it, loss=0.058, nmi=1.000]
# (10500,)
# <class 'numpy.ndarray'>
#   4%|▍         | 4/100 [44:08<17:38:16, 661.42s/it, loss=0.018, nmi=1.000]
# (10500,)
# <class 'numpy.ndarray'>
#   5%|▌         | 5/100 [53:39<16:35:54, 628.99s/it, loss=0.005, nmi=1.000]
# (10500,)
# <class 'numpy.ndarray'>
#   6%|▌         | 6/100 [1:03:04<15:51:05, 607.08s/it, loss=0.002, nmi=1.000]
# (10500,)
# <class 'numpy.ndarray'>
#   7%|▋         | 7/100 [1:12:28<15:19:06, 592.97s/it, loss=0.002, nmi=1.000]
# (10500,)
# <class 'numpy.ndarray'>
#   8%|▊         | 8/100 [1:21:46<14:52:22, 581.99s/it, loss=0.002, nmi=1.000]
# (10500,)
# <class 'numpy.ndarray'>
#   9%|▉         | 9/100 [1:31:10<14:33:44, 576.09s/it, loss=0.002, nmi=1.000]
# (10500,)
# <class 'numpy.ndarray'>
#   9%|▉         | 9/100 [1:33:42<15:47:31, 624.74s/it, loss=0.002, nmi=1.000]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-f47c7d0dc5eb> in <module>()
#      59
#      60 if __name__ == '__main__':
# ---> 61     main()
#
# <ipython-input-13-f47c7d0dc5eb> in main()
#      42             loss = model.loss(X_hat, X_train, args.beta, args.rho)
#      43
# ---> 44             pred_labels = model.get_cluster()
#      45             print(pred_labels.shape)
#      46             print(type(pred_labels))
#
# /content/drive/.shortcut-targets-by-id/1TNHdJkAXnDAdPZ4uzztu_RrLScIxYZuJ/CS245 Project Shared/eva/src/model.py in get_cluster(self)
#      60
#      61     def get_cluster(self):
# ---> 62         kmeans = KMeans(n_clusters=self.clusters).fit(self.outputs['lin2'].detach().cpu().numpy())
#      63         self.centroids = kmeans.cluster_centers_
#      64         return kmeans.labels_
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1181             # Initialize centers
#    1182             centers_init = self._init_centroids(
# -> 1183                 X, x_squared_norms=x_squared_norms, init=init, random_state=random_state
#    1184             )
#    1185             if self.verbose:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in _init_centroids(self, X, x_squared_norms, init, random_state, init_size)
#    1095                 n_clusters,
#    1096                 random_state=random_state,
# -> 1097                 x_squared_norms=x_squared_norms,
#    1098             )
#    1099         elif isinstance(init, str) and init == "random":
#
# /usr/local/lib/python3.7/dist-packages/sklearn/cluster/_kmeans.py in _kmeans_plusplus(X, n_clusters, x_squared_norms, random_state, n_local_trials)
#     217         # Compute distances to center candidates
#     218         distance_to_candidates = _euclidean_distances(
# --> 219             X[candidate_ids], X, Y_norm_squared=x_squared_norms, squared=True
#     220         )
#     221
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/pairwise.py in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     363         # To minimize precision issues with float32, we compute the distance
#     364         # matrix on chunks of X and Y upcast to float64
# --> 365         distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     366     else:
#     367         # if dtype is already float64, no need to chunk and upcast
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/pairwise.py in _euclidean_distances_upcast(X, XX, Y, YY, batch_size)
#     560                     YY_chunk = YY[:, y_slice]
#     561
# --> 562                 d = -2 * safe_sparse_dot(X_chunk, Y_chunk.T, dense_output=True)
#     563                 d += XX_chunk
#     564                 d += YY_chunk
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (
#
# KeyboardInterrupt:

# %% [markdown]
# # NEW APPROACH
